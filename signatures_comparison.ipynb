# %%
import pandas as pd
import os
import glob
from Bio import SeqIO
import csv

# %% [markdown]
# To run this notebook, the working directory must contain three subdirectories:
#
# 1. interpro_outputs – InterProScan outputs for all processed (merged_nr) sequences.
# 2. interpro_refs_outputs – InterProScan outputs for all reference sequences.
# 3. merged_nr_fastas – FASTA files of all processed sequences in the database.

# %% [markdown]
# ## Filter 1 - Selecting sequences that have the essential signatures

# %%
essential_signatures = {
    "SIAE": "PF03629",
    "kpsD": "PF02563",
    "kpsE": "PTHR32309",
    "kpsM": "PF01061",
    "kpsT": "cd03220",
    "lic3A": "PF06002",
    "lic3B": "PF06002",
    "lst": "PF07922",
    "cpsK": "PF07922",
    "nagA": "cd00854",
    "nagB": "cd01399",
    "nanA": "PTHR42849",
    "nanC": "PF06178",
    "nanE": "PF04131",
    "nanH": "cd15482",
    "nanK": "PTHR18964",
    "nanM": "PF24996",
    "nanQ": "PF04074",
    "nanR": "cd07377",
    "nanT": "cd17316",
    "nanU": "cd08977",
    "neuA": "cd02513",
    "neuB": "cd11615",
    "neuC": "TIGR03568",
    "neuD": "cd03360",
    "neuE": "PF20471",
    "neuO": "cd04647",
    "neuS": "PF07388",
    "ompC": "PF00267",
    "ompF": "PF00267",
    "satA": "PTHR30290",
    "satB": "PTHR43163",
    "satC": "PTHR43297",
    "satD": "PTHR43776",
    "siaM": "PF06808",
    "siaT": "PF06808",
    "siaP": "PF03480",
    "siaQ": "PF04290"  
}

# %%
# Function to parse InterProScan output

def read_interproscan_tsv(file):
    columns = [
        "seq_id", "md5", "length", "analysis", "signature_accession",
        "signature_desc", "start", "end", "evalue", "status",
        "date", "ipr", "ipr_desc", "go", "pathway"
    ]
    try:
        df = pd.read_csv(file, sep="\t", header=None, names=columns, usecols=[0, 4])
        return df
    except Exception as e:
        print(f"Error reading {file}: {e}")
        return pd.DataFrame(columns=["seq_id", "signature_accession"])

# %%
# Identifying IDs that contain the essential signature

interpro_folder = "./interpro_outputs"
output_folder = "./IDs_filter1"

os.makedirs(output_folder, exist_ok=True)

for gene, signature in essential_signatures.items():
    print(f"\n=== Processing {gene} (signature: {signature}) ===")

    interpro_file = f"{gene}_interproscan.tsv"
    interpro_path = os.path.join(interpro_folder, interpro_file)

    if not os.path.exists(interpro_path):
        print(f"[ERROR] File not found: {interpro_path}. Skipping...")
        continue

    df = read_interproscan_tsv(interpro_path)

    if df.empty:
        print(f"[WARNING] Empty file for {gene}.")
        continue

    # --- FILTER BY SIGNATURE ---
    df_filtered = df[df["signature_accession"] == signature]

    # --- REMOVE DUPLICATES ---
    # Deduplicate only by seq_id
    df_filtered = df_filtered.drop_duplicates(subset=["seq_id"])

    # Output file name
    output_file = os.path.join(
        output_folder,
        f"{gene}_IDs_filter1.tsv"
    )

    df_filtered[["seq_id"]].to_csv(output_file, sep="\t", index=False, header=True)

    print(f"Rows found (after deduplication): {len(df_filtered)}")
    print(f"File saved to: {output_file}")
# Out:
# === Processing SIAE (signature: PF03629) ===
# Rows found (after deduplication): 113516
# File saved to: ./IDs_filter1/SIAE_IDs_filter1.tsv
#
# === Processing kpsD (signature: PF02563) ===
# Rows found (after deduplication): 12824
# File saved to: ./IDs_filter1/kpsD_IDs_filter1.tsv
#
# === Processing kpsE (signature: PTHR32309) ===
# Rows found (after deduplication): 10297
# File saved to: ./IDs_filter1/kpsE_IDs_filter1.tsv
#
# === Processing kpsM (signature: PF01061) ===
# Rows found (after deduplication): 1045
# File saved to: ./IDs_filter1/kpsM_IDs_filter1.tsv
#
# === Processing kpsT (signature: cd03220) ===
# Rows found (after deduplication): 12389
# File saved to: ./IDs_filter1/kpsT_IDs_filter1.tsv
#
# === Processing lic3A (signature: PF06002) ===
# Rows found (after deduplication): 1394
# File saved to: ./IDs_filter1/lic3A_IDs_filter1.tsv
#
# === Processing lic3B (signature: PF06002) ===
# Rows found (after deduplication): 3
# File saved to: ./IDs_filter1/lic3B_IDs_filter1.tsv
#
# === Processing lst (signature: PF07922) ===
# Rows found (after deduplication): 2057
# File saved to: ./IDs_filter1/lst_IDs_filter1.tsv
#
# === Processing cpsK (signature: PF07922) ===
# Rows found (after deduplication): 33
# File saved to: ./IDs_filter1/cpsK_IDs_filter1.tsv
#
# === Processing nagA (signature: cd00854) ===
# Rows found (after deduplication): 123809
# File saved to: ./IDs_filter1/nagA_IDs_filter1.tsv
#
# === Processing nagB (signature: cd01399) ===
# Rows found (after deduplication): 141064
# File saved to: ./IDs_filter1/nagB_IDs_filter1.tsv
#
# === Processing nanA (signature: PTHR42849) ===
# Rows found (after deduplication): 31161
# File saved to: ./IDs_filter1/nanA_IDs_filter1.tsv
#
# === Processing nanC (signature: PF06178) ===
# Rows found (after deduplication): 3427
# File saved to: ./IDs_filter1/nanC_IDs_filter1.tsv
#
# === Processing nanE (signature: PF04131) ===
# Rows found (after deduplication): 38622
# File saved to: ./IDs_filter1/nanE_IDs_filter1.tsv
#
# === Processing nanH (signature: cd15482) ===
# Rows found (after deduplication): 56427
# File saved to: ./IDs_filter1/nanH_IDs_filter1.tsv
#
# === Processing nanK (signature: PTHR18964) ===
# Rows found (after deduplication): 30746
# File saved to: ./IDs_filter1/nanK_IDs_filter1.tsv
#
# === Processing nanM (signature: PF24996) ===
# Rows found (after deduplication): 5511
# File saved to: ./IDs_filter1/nanM_IDs_filter1.tsv
#
# === Processing nanQ (signature: PF04074) ===
# Rows found (after deduplication): 12456
# File saved to: ./IDs_filter1/nanQ_IDs_filter1.tsv
#
# === Processing nanR (signature: cd07377) ===
# Rows found (after deduplication): 11866
# File saved to: ./IDs_filter1/nanR_IDs_filter1.tsv
#
# === Processing nanT (signature: cd17316) ===
# Rows found (after deduplication): 8210
# File saved to: ./IDs_filter1/nanT_IDs_filter1.tsv
#
# === Processing nanU (signature: cd08977) ===
# Rows found (after deduplication): 150555
# File saved to: ./IDs_filter1/nanU_IDs_filter1.tsv
#
# === Processing neuA (signature: cd02513) ===
# Rows found (after deduplication): 46800
# File saved to: ./IDs_filter1/neuA_IDs_filter1.tsv
#
# === Processing neuB (signature: cd11615) ===
# Rows found (after deduplication): 54579
# File saved to: ./IDs_filter1/neuB_IDs_filter1.tsv
#
# === Processing neuC (signature: TIGR03568) ===
# Rows found (after deduplication): 20703
# File saved to: ./IDs_filter1/neuC_IDs_filter1.tsv
#
# === Processing neuD (signature: cd03360) ===
# Rows found (after deduplication): 15906
# File saved to: ./IDs_filter1/neuD_IDs_filter1.tsv
#
# === Processing neuE (signature: PF20471) ===
# Rows found (after deduplication): 12
# File saved to: ./IDs_filter1/neuE_IDs_filter1.tsv
#
# === Processing neuO (signature: cd04647) ===
# Rows found (after deduplication): 126
# File saved to: ./IDs_filter1/neuO_IDs_filter1.tsv
#
# === Processing neuS (signature: PF07388) ===
# Rows found (after deduplication): 22
# File saved to: ./IDs_filter1/neuS_IDs_filter1.tsv
#
# === Processing ompC (signature: PF00267) ===
# Rows found (after deduplication): 17380
# File saved to: ./IDs_filter1/ompC_IDs_filter1.tsv
#
# === Processing ompF (signature: PF00267) ===
# Rows found (after deduplication): 10653
# File saved to: ./IDs_filter1/ompF_IDs_filter1.tsv
#
# === Processing satA (signature: PTHR30290) ===
# Rows found (after deduplication): 4738
# File saved to: ./IDs_filter1/satA_IDs_filter1.tsv
#
# === Processing satB (signature: PTHR43163) ===
# Rows found (after deduplication): 4710
# File saved to: ./IDs_filter1/satB_IDs_filter1.tsv
#
# === Processing satC (signature: PTHR43297) ===
# Rows found (after deduplication): 952
# File saved to: ./IDs_filter1/satC_IDs_filter1.tsv
#
# === Processing satD (signature: PTHR43776) ===
# Rows found (after deduplication): 4887
# File saved to: ./IDs_filter1/satD_IDs_filter1.tsv
#
# === Processing siaM (signature: PF06808) ===
# Rows found (after deduplication): 295868
# File saved to: ./IDs_filter1/siaM_IDs_filter1.tsv
#
# === Processing siaT (signature: PF06808) ===
# Rows found (after deduplication): 75387
# File saved to: ./IDs_filter1/siaT_IDs_filter1.tsv
#
# === Processing siaP (signature: PF03480) ===
# Rows found (after deduplication): 271279
# File saved to: ./IDs_filter1/siaP_IDs_filter1.tsv
#
# === Processing siaQ (signature: PF04290) ===
# Rows found (after deduplication): 75718
# File saved to: ./IDs_filter1/siaQ_IDs_filter1.tsv

# %%
# Retrieving only InterProScan output entries corresponding to sequences
# that contain the essential signature
# Expanded code for all proteins

# === DIRECTORIES ===
signatures_folder = "./IDs_filter1"
interpro_folder = "./interpro_outputs"        # where *_interproscan.tsv are stored
output_folder = "./interpro_outputs_filter1"

os.makedirs(output_folder, exist_ok=True)

# === LOOP FOR ALL SIGNATURE FILES ===
for sig_file in glob.glob(os.path.join(signatures_folder, "*_IDs_filter1.tsv")):
    
    # extract gene name from filename
    gene = os.path.basename(sig_file).replace("_IDs_filter1.tsv", "")
    
    # corresponding InterProScan file
    interpro_file = os.path.join(interpro_folder, f"{gene}_interproscan.tsv")
    
    # if missing, skip
    if not os.path.exists(interpro_file):
        print(f"[WARNING] InterProScan file not found for {gene}")
        continue
    
    print(f"Processing {gene}...")
    
    # load files
    df_ids = pd.read_csv(sig_file, sep="\t")                    # has header
    df_inter = pd.read_csv(interpro_file, sep="\t", header=None)  # no header
    
    # first column of ID file
    ids_column = df_ids.columns[0]
    
    # filtering
    df_filtered = df_inter[df_inter[0].isin(df_ids[ids_column])]
    
    # save
    out = os.path.join(output_folder, f"{gene}_interproscan_filter1.tsv")
    df_filtered.to_csv(out, sep="\t", index=False, header=False)
    
print("\n### PROCESSING COMPLETED ###")
# Out:
# Processing nanR...
# Processing nagB...
# Processing nagA...
# Processing neuO...
# Processing satA...
# Processing nanQ...
# Processing kpsD...
# Processing lst...
# Processing lic3A...
# Processing satC...
# Processing nanA...
# Processing nanT...
# Processing neuS...
# Processing lic3B...
# Processing siaM...
# Processing nanE...
# Processing kpsT...
# Processing satB...
# Processing nanK...
# Processing neuA...
# Processing SIAE...
# Processing neuD...
# Processing neuE...
# Processing neuB...
# Processing nanU...
# Processing cpsK...
# Processing nanM...
# Processing nanC...
# Processing satD...
# Processing kpsE...
# Processing ompC...
# Processing siaP...
# Processing kpsM...
# Processing ompF...
# Processing neuC...
# Processing siaT...
# Processing siaQ...
# Processing nanH...
#
# ### PROCESSING COMPLETED ###

# %% [markdown]
# ## Filter 2 - Selecting IDs that have the essential signature and no extra signatures
#
# Extra signatures are understood to be those that are not present for any of the references

# %%
# Generating a summary of the signatures identified in the references

path = "./interpro_refs_outputs"
files = glob.glob(os.path.join(path, "*.tsv"))

# Columns according to the InterProScan manual
columns = [
    "protein_accession",
    "md5",
    "seq_length",
    "analysis",
    "signature_accession",
    "signature_description",
    "start",
    "stop",
    "score",
    "status",
    "date",
    "ipr_accession",
    "ipr_description",
    "go_terms",
    "pathways"
]

dataframes = []

for file in files:
    # Read file
    df = pd.read_csv(file, sep="\t", names=columns, comment="#", dtype=str)

    # Extract gene name from file name
    gene_name = os.path.basename(file).split("_")[0]
    df["gene"] = gene_name

    # Select only desired columns
    df = df[[
        "gene",
        "protein_accession",
        "analysis",
        "signature_accession",
        "signature_description",
        "ipr_accession",
        "ipr_description"
    ]]

    # Remove exact duplicates (optional, avoids repetition)
    df = df.drop_duplicates()

    dataframes.append(df)

# Concatenate all genes
df_final = pd.concat(dataframes, ignore_index=True)

# Save final result with quotes in all cells
df_final.to_csv(
    "interproscan_ref_summary.csv",
    index=False,
    quoting=csv.QUOTE_ALL,
    encoding="utf-8")

# %%
# Filtering

interpro_folder = "./interpro_outputs_filter1"
ref_file = "./interproscan_ref_summary.csv"  
output_folder = "./suspect_IDs"

os.makedirs(output_folder, exist_ok=True)

# Read reference file
df_ref = pd.read_csv(ref_file)

# Process all .tsv files
files = [f for f in os.listdir(interpro_folder) if f.endswith(".tsv")]

print(f"Found {len(files)} files to process.")

for file in files:
    path = os.path.join(interpro_folder, file)
    gene = file.split("_")[0]

    print(f"\n=== Processing gene: {gene} ===")

    df_gene = read_interproscan_tsv(path)
    df_ref_gene = df_ref[df_ref["gene"] == gene]

    if df_ref_gene.empty:
        print(f"No reference found for {gene}. Skipping...")
        continue

    signatures_ref = set(df_ref_gene["signature_accession"].dropna().astype(str).unique())

    df_gene["signature_accession"] = df_gene["signature_accession"].astype(str)

    suspect_ids = df_gene[
        ~df_gene["signature_accession"].isin(signatures_ref)
    ]["seq_id"].unique()

    df_output = df_gene[df_gene["seq_id"].isin(suspect_ids)]

    outpath = os.path.join(output_folder, f"{gene}_suspect_IDs.tsv")
    df_output[["seq_id"]].drop_duplicates().to_csv(
        outpath,
        sep="\t",
        index=False
    )

    print(f"File generated: {outpath} ({len(df_output)} rows)")

print("\nProcessing completed! 👍")
# Out:
# Found 38 files to process.
#
# === Processing gene: nanT ===
# File generated: ./suspect_IDs/nanT_suspect_IDs.tsv (37518 rows)
#
# === Processing gene: siaP ===
# File generated: ./suspect_IDs/siaP_suspect_IDs.tsv (1649317 rows)
#
# === Processing gene: nanK ===
# File generated: ./suspect_IDs/nanK_suspect_IDs.tsv (132474 rows)
#
# === Processing gene: nagB ===
# File generated: ./suspect_IDs/nagB_suspect_IDs.tsv (529826 rows)
#
# === Processing gene: satA ===
# File generated: ./suspect_IDs/satA_suspect_IDs.tsv (39436 rows)
#
# === Processing gene: siaM ===
# File generated: ./suspect_IDs/siaM_suspect_IDs.tsv (102035 rows)
#
# === Processing gene: nagA ===
# File generated: ./suspect_IDs/nagA_suspect_IDs.tsv (97972 rows)
#
# === Processing gene: satC ===
# File generated: ./suspect_IDs/satC_suspect_IDs.tsv (9614 rows)
#
# === Processing gene: satD ===
# File generated: ./suspect_IDs/satD_suspect_IDs.tsv (34756 rows)
#
# === Processing gene: kpsT ===
# File generated: ./suspect_IDs/kpsT_suspect_IDs.tsv (9550 rows)
#
# === Processing gene: lst ===
# File generated: ./suspect_IDs/lst_suspect_IDs.tsv (114 rows)
#
# === Processing gene: nanQ ===
# File generated: ./suspect_IDs/nanQ_suspect_IDs.tsv (5920 rows)
#
# === Processing gene: neuO ===
# File generated: ./suspect_IDs/neuO_suspect_IDs.tsv (141 rows)
#
# === Processing gene: neuA ===
# File generated: ./suspect_IDs/neuA_suspect_IDs.tsv (216427 rows)
#
# === Processing gene: neuS ===
# File generated: ./suspect_IDs/neuS_suspect_IDs.tsv (0 rows)
#
# === Processing gene: lic3A ===
# File generated: ./suspect_IDs/lic3A_suspect_IDs.tsv (504 rows)
#
# === Processing gene: neuC ===
# File generated: ./suspect_IDs/neuC_suspect_IDs.tsv (11942 rows)
#
# === Processing gene: nanH ===
# File generated: ./suspect_IDs/nanH_suspect_IDs.tsv (326844 rows)
#
# === Processing gene: nanA ===
# File generated: ./suspect_IDs/nanA_suspect_IDs.tsv (178557 rows)
#
# === Processing gene: siaQ ===
# File generated: ./suspect_IDs/siaQ_suspect_IDs.tsv (31541 rows)
#
# === Processing gene: nanM ===
# File generated: ./suspect_IDs/nanM_suspect_IDs.tsv (7200 rows)
#
# === Processing gene: kpsE ===
# File generated: ./suspect_IDs/kpsE_suspect_IDs.tsv (23665 rows)
#
# === Processing gene: neuD ===
# File generated: ./suspect_IDs/neuD_suspect_IDs.tsv (24100 rows)
#
# === Processing gene: lic3B ===
# File generated: ./suspect_IDs/lic3B_suspect_IDs.tsv (0 rows)
#
# === Processing gene: nanU ===
# File generated: ./suspect_IDs/nanU_suspect_IDs.tsv (790619 rows)
#
# === Processing gene: kpsM ===
# File generated: ./suspect_IDs/kpsM_suspect_IDs.tsv (272 rows)
#
# === Processing gene: neuE ===
# File generated: ./suspect_IDs/neuE_suspect_IDs.tsv (2 rows)
#
# === Processing gene: nanR ===
# File generated: ./suspect_IDs/nanR_suspect_IDs.tsv (20517 rows)
#
# === Processing gene: nanC ===
# File generated: ./suspect_IDs/nanC_suspect_IDs.tsv (10536 rows)
#
# === Processing gene: ompC ===
# File generated: ./suspect_IDs/ompC_suspect_IDs.tsv (207738 rows)
#
# === Processing gene: nanE ===
# File generated: ./suspect_IDs/nanE_suspect_IDs.tsv (19511 rows)
#
# === Processing gene: kpsD ===
# File generated: ./suspect_IDs/kpsD_suspect_IDs.tsv (120745 rows)
#
# === Processing gene: neuB ===
# File generated: ./suspect_IDs/neuB_suspect_IDs.tsv (269311 rows)
#
# === Processing gene: cpsK ===
# File generated: ./suspect_IDs/cpsK_suspect_IDs.tsv (6 rows)
#
# === Processing gene: siaT ===
# File generated: ./suspect_IDs/siaT_suspect_IDs.tsv (25967 rows)
#
# === Processing gene: ompF ===
# File generated: ./suspect_IDs/ompF_suspect_IDs.tsv (9383 rows)
#
# === Processing gene: SIAE ===
# File generated: ./suspect_IDs/SIAE_suspect_IDs.tsv (414453 rows)
#
# === Processing gene: satB ===
# File generated: ./suspect_IDs/satB_suspect_IDs.tsv (647 rows)
#
# Processing completed! 👍

# %% [markdown]
# ## Compiling FASTA files

# %%
# Code to identify which IDs are present in IDs_filter1 but not in suspect_IDs
# In other words, retrieve IDs of sequences that contain the essential signature
# and remove IDs of sequences that contain additional signatures

dir_filter1 = "IDs_filter1"
dir_suspects = "suspect_IDs"
dir_output = "IDs_filter2"

os.makedirs(dir_output, exist_ok=True)

# List files in directories
files_filter1 = {f.split("_")[0]: f for f in os.listdir(dir_filter1)}
files_suspects = {f.split("_")[0]: f for f in os.listdir(dir_suspects)}

genes = sorted(set(files_filter1.keys()) & set(files_suspects.keys()))

for gene in genes:
    file_filter1 = os.path.join(dir_filter1, files_filter1[gene])
    file_suspects = os.path.join(dir_suspects, files_suspects[gene])

    # Read files (automatic separator detection)
    df_filter1 = pd.read_csv(file_filter1, engine="python")
    df_suspects = pd.read_csv(file_suspects, engine="python")

    # Extract IDs
    ids_filter1 = set(df_filter1["seq_id"])
    ids_suspects = set(df_suspects["seq_id"])

    # Difference
    unique_ids = sorted(ids_filter1 - ids_suspects)

    # Save output file
    out_file = os.path.join(dir_output, f"{gene}_filter2_IDs.tsv")
    df_out = pd.DataFrame({"seq_id": unique_ids})
    df_out.to_csv(out_file, sep="\t", index=False, header=True)

    print(f"{gene}: {len(unique_ids)} filter 2 IDs saved.")

print("\n✔️ Process completed!")
# Out:
# SIAE: 60165 filter 2 IDs saved.
# cpsK: 31 filter 2 IDs saved.
# kpsD: 2938 filter 2 IDs saved.
# kpsE: 6598 filter 2 IDs saved.
# kpsM: 1012 filter 2 IDs saved.
# kpsT: 11445 filter 2 IDs saved.
# lic3A: 1278 filter 2 IDs saved.
# lic3B: 3 filter 2 IDs saved.
# lst: 2022 filter 2 IDs saved.
# nagA: 114823 filter 2 IDs saved.
# nagB: 85856 filter 2 IDs saved.
# nanA: 14001 filter 2 IDs saved.
# nanC: 1029 filter 2 IDs saved.
# nanE: 36663 filter 2 IDs saved.
# nanH: 22950 filter 2 IDs saved.
# nanK: 11298 filter 2 IDs saved.
# nanM: 4458 filter 2 IDs saved.
# nanQ: 11433 filter 2 IDs saved.
# nanR: 10517 filter 2 IDs saved.
# nanT: 4172 filter 2 IDs saved.
# nanU: 27378 filter 2 IDs saved.
# neuA: 22064 filter 2 IDs saved.
# neuB: 31211 filter 2 IDs saved.
# neuC: 19190 filter 2 IDs saved.
# neuD: 13279 filter 2 IDs saved.
# neuE: 11 filter 2 IDs saved.
# neuO: 114 filter 2 IDs saved.
# neuS: 22 filter 2 IDs saved.
# ompC: 5201 filter 2 IDs saved.
# ompF: 10057 filter 2 IDs saved.
# satA: 922 filter 2 IDs saved.
# satB: 4631 filter 2 IDs saved.
# satC: 396 filter 2 IDs saved.
# satD: 1681 filter 2 IDs saved.
# siaM: 278572 filter 2 IDs saved.
# siaP: 40420 filter 2 IDs saved.
# siaQ: 67497 filter 2 IDs saved.
# siaT: 70217 filter 2 IDs saved.
#
# ✔️ Process completed!

# %%
# Extracting FASTA sequences with essential signatures

dir_fastas = "merged_nr_fastas"                  # Original FASTA files
dir_ids = "IDs_filter1"                          # TSV files with approved seq_id
dir_output = "FASTAS_with_essential_signature"   # Final FASTA files

os.makedirs(dir_output, exist_ok=True)

# Map files by gene (before the first "_")
fastas = {f.split("_")[0]: f for f in os.listdir(dir_fastas) if f.endswith(".fasta")}
idfiles = {f.split("_")[0]: f for f in os.listdir(dir_ids) if f.endswith(".tsv")}

# Genes in common
genes = sorted(set(fastas.keys()) & set(idfiles.keys()))

print(f"Processing {len(genes)} genes...\n")

for gene in genes:

    fasta_path = os.path.join(dir_fastas, fastas[gene])
    ids_path = os.path.join(dir_ids, idfiles[gene])

    print(f"→ {gene}")

    # Read approved IDs
    df = pd.read_csv(ids_path, sep="\t")
    approved_ids = set(df["seq_id"].astype(str))

    # Read original FASTA
    records = list(SeqIO.parse(fasta_path, "fasta"))

    # Filter sequences whose header is in the list
    filtered = [
        r for r in records
        if r.id in approved_ids
    ]

    # Output file
    out_fasta = os.path.join(dir_output, f"{gene}_with_essential_signature.fasta")

    SeqIO.write(filtered, out_fasta, "fasta")

    print(f"   ✔ {len(filtered)} sequences saved to {out_fasta}")

print("\n✔ Finished!")
# Out:
# Processing 38 genes...
#
# → SIAE
#    ✔ 113516 sequences saved to FASTAS_with_essential_signature/SIAE_with_essential_signature.fasta
# → cpsK
#    ✔ 33 sequences saved to FASTAS_with_essential_signature/cpsK_with_essential_signature.fasta
# → kpsD
#    ✔ 12824 sequences saved to FASTAS_with_essential_signature/kpsD_with_essential_signature.fasta
# → kpsE
#    ✔ 10297 sequences saved to FASTAS_with_essential_signature/kpsE_with_essential_signature.fasta
# → kpsM
#    ✔ 1045 sequences saved to FASTAS_with_essential_signature/kpsM_with_essential_signature.fasta
# → kpsT
#    ✔ 12389 sequences saved to FASTAS_with_essential_signature/kpsT_with_essential_signature.fasta
# → lic3A
#    ✔ 1394 sequences saved to FASTAS_with_essential_signature/lic3A_with_essential_signature.fasta
# → lic3B
#    ✔ 3 sequences saved to FASTAS_with_essential_signature/lic3B_with_essential_signature.fasta
# → lst
#    ✔ 2057 sequences saved to FASTAS_with_essential_signature/lst_with_essential_signature.fasta
# → nagA
#    ✔ 123809 sequences saved to FASTAS_with_essential_signature/nagA_with_essential_signature.fasta
# → nagB
#    ✔ 141064 sequences saved to FASTAS_with_essential_signature/nagB_with_essential_signature.fasta
# → nanA
#    ✔ 31161 sequences saved to FASTAS_with_essential_signature/nanA_with_essential_signature.fasta
# → nanC
#    ✔ 3427 sequences saved to FASTAS_with_essential_signature/nanC_with_essential_signature.fasta
# → nanE
#    ✔ 38622 sequences saved to FASTAS_with_essential_signature/nanE_with_essential_signature.fasta
# → nanH
#    ✔ 56427 sequences saved to FASTAS_with_essential_signature/nanH_with_essential_signature.fasta
# → nanK
#    ✔ 30746 sequences saved to FASTAS_with_essential_signature/nanK_with_essential_signature.fasta
# → nanM
#    ✔ 5511 sequences saved to FASTAS_with_essential_signature/nanM_with_essential_signature.fasta
# → nanQ
#    ✔ 12456 sequences saved to FASTAS_with_essential_signature/nanQ_with_essential_signature.fasta
# → nanR
#    ✔ 11866 sequences saved to FASTAS_with_essential_signature/nanR_with_essential_signature.fasta
# → nanT
#    ✔ 8210 sequences saved to FASTAS_with_essential_signature/nanT_with_essential_signature.fasta
# → nanU
#    ✔ 150555 sequences saved to FASTAS_with_essential_signature/nanU_with_essential_signature.fasta
# → neuA
#    ✔ 46800 sequences saved to FASTAS_with_essential_signature/neuA_with_essential_signature.fasta
# → neuB
#    ✔ 54579 sequences saved to FASTAS_with_essential_signature/neuB_with_essential_signature.fasta
# → neuC
#    ✔ 20703 sequences saved to FASTAS_with_essential_signature/neuC_with_essential_signature.fasta
# → neuD
#    ✔ 15906 sequences saved to FASTAS_with_essential_signature/neuD_with_essential_signature.fasta
# → neuE
#    ✔ 12 sequences saved to FASTAS_with_essential_signature/neuE_with_essential_signature.fasta
# → neuO
#    ✔ 126 sequences saved to FASTAS_with_essential_signature/neuO_with_essential_signature.fasta
# → neuS
#    ✔ 22 sequences saved to FASTAS_with_essential_signature/neuS_with_essential_signature.fasta
# → ompC
#    ✔ 17380 sequences saved to FASTAS_with_essential_signature/ompC_with_essential_signature.fasta
# → ompF
#    ✔ 10653 sequences saved to FASTAS_with_essential_signature/ompF_with_essential_signature.fasta
# → satA
#    ✔ 4738 sequences saved to FASTAS_with_essential_signature/satA_with_essential_signature.fasta
# → satB
#    ✔ 4710 sequences saved to FASTAS_with_essential_signature/satB_with_essential_signature.fasta
# → satC
#    ✔ 952 sequences saved to FASTAS_with_essential_signature/satC_with_essential_signature.fasta
# → satD
#    ✔ 4887 sequences saved to FASTAS_with_essential_signature/satD_with_essential_signature.fasta
# → siaM
#    ✔ 295868 sequences saved to FASTAS_with_essential_signature/siaM_with_essential_signature.fasta
# → siaP
#    ✔ 271279 sequences saved to FASTAS_with_essential_signature/siaP_with_essential_signature.fasta
# → siaQ
#    ✔ 75718 sequences saved to FASTAS_with_essential_signature/siaQ_with_essential_signature.fasta
# → siaT
#    ✔ 75387 sequences saved to FASTAS_with_essential_signature/siaT_with_essential_signature.fasta
#
# ✔ Finished!

# %%
# Extracting FASTA sequences with essential signatures and without any extra signatures

dir_fastas = "merged_nr_fastas"        # Original FASTA files
dir_ids = "IDs_filter2"                  # TSV files with approved seq_id
dir_output = "FASTAS_without_extra"            # Final FASTA files

os.makedirs(dir_output, exist_ok=True)

# Map files by gene (before the first "_")
fastas = {f.split("_")[0]: f for f in os.listdir(dir_fastas) if f.endswith(".fasta")}
idfiles = {f.split("_")[0]: f for f in os.listdir(dir_ids) if f.endswith(".tsv")}

# Genes in common
genes = sorted(set(fastas.keys()) & set(idfiles.keys()))

print(f"Processing {len(genes)} genes...\n")

for gene in genes:

    fasta_path = os.path.join(dir_fastas, fastas[gene])
    ids_path = os.path.join(dir_ids, idfiles[gene])

    print(f"→ {gene}")

    # Read approved IDs
    df = pd.read_csv(ids_path, sep="\t")
    approved_ids = set(df["seq_id"].astype(str))

    # Read original FASTA
    records = list(SeqIO.parse(fasta_path, "fasta"))

    # Filter sequences whose header is in the list
    filtered = [
        r for r in records
        if r.id in approved_ids
    ]

    # Output file
    out_fasta = os.path.join(dir_output, f"{gene}_without_extra.fasta")

    SeqIO.write(filtered, out_fasta, "fasta")

    print(f"   ✔ {len(filtered)} sequences saved to {out_fasta}")

print("\n✔ Finished!")
# Out:
# Processing 38 genes...
#
# → SIAE
#    ✔ 60165 sequences saved to FASTAS_without_extra/SIAE_without_extra.fasta
# → cpsK
#    ✔ 31 sequences saved to FASTAS_without_extra/cpsK_without_extra.fasta
# → kpsD
#    ✔ 2938 sequences saved to FASTAS_without_extra/kpsD_without_extra.fasta
# → kpsE
#    ✔ 6598 sequences saved to FASTAS_without_extra/kpsE_without_extra.fasta
# → kpsM
#    ✔ 1012 sequences saved to FASTAS_without_extra/kpsM_without_extra.fasta
# → kpsT
#    ✔ 11445 sequences saved to FASTAS_without_extra/kpsT_without_extra.fasta
# → lic3A
#    ✔ 1278 sequences saved to FASTAS_without_extra/lic3A_without_extra.fasta
# → lic3B
#    ✔ 3 sequences saved to FASTAS_without_extra/lic3B_without_extra.fasta
# → lst
#    ✔ 2022 sequences saved to FASTAS_without_extra/lst_without_extra.fasta
# → nagA
#    ✔ 114823 sequences saved to FASTAS_without_extra/nagA_without_extra.fasta
# → nagB
#    ✔ 85856 sequences saved to FASTAS_without_extra/nagB_without_extra.fasta
# → nanA
#    ✔ 14001 sequences saved to FASTAS_without_extra/nanA_without_extra.fasta
# → nanC
#    ✔ 1029 sequences saved to FASTAS_without_extra/nanC_without_extra.fasta
# → nanE
#    ✔ 36663 sequences saved to FASTAS_without_extra/nanE_without_extra.fasta
# → nanH
#    ✔ 22950 sequences saved to FASTAS_without_extra/nanH_without_extra.fasta
# → nanK
#    ✔ 11298 sequences saved to FASTAS_without_extra/nanK_without_extra.fasta
# → nanM
#    ✔ 4458 sequences saved to FASTAS_without_extra/nanM_without_extra.fasta
# → nanQ
#    ✔ 11433 sequences saved to FASTAS_without_extra/nanQ_without_extra.fasta
# → nanR
#    ✔ 10517 sequences saved to FASTAS_without_extra/nanR_without_extra.fasta
# → nanT
#    ✔ 4172 sequences saved to FASTAS_without_extra/nanT_without_extra.fasta
# → nanU
#    ✔ 27378 sequences saved to FASTAS_without_extra/nanU_without_extra.fasta
# → neuA
#    ✔ 22064 sequences saved to FASTAS_without_extra/neuA_without_extra.fasta
# → neuB
#    ✔ 31211 sequences saved to FASTAS_without_extra/neuB_without_extra.fasta
# → neuC
#    ✔ 19190 sequences saved to FASTAS_without_extra/neuC_without_extra.fasta
# → neuD
#    ✔ 13279 sequences saved to FASTAS_without_extra/neuD_without_extra.fasta
# → neuE
#    ✔ 11 sequences saved to FASTAS_without_extra/neuE_without_extra.fasta
# → neuO
#    ✔ 114 sequences saved to FASTAS_without_extra/neuO_without_extra.fasta
# → neuS
#    ✔ 22 sequences saved to FASTAS_without_extra/neuS_without_extra.fasta
# → ompC
#    ✔ 5201 sequences saved to FASTAS_without_extra/ompC_without_extra.fasta
# → ompF
#    ✔ 10057 sequences saved to FASTAS_without_extra/ompF_without_extra.fasta
# → satA
#    ✔ 922 sequences saved to FASTAS_without_extra/satA_without_extra.fasta
# → satB
#    ✔ 4631 sequences saved to FASTAS_without_extra/satB_without_extra.fasta
# → satC
#    ✔ 396 sequences saved to FASTAS_without_extra/satC_without_extra.fasta
# → satD
#    ✔ 1681 sequences saved to FASTAS_without_extra/satD_without_extra.fasta
# → siaM
#    ✔ 278572 sequences saved to FASTAS_without_extra/siaM_without_extra.fasta
# → siaP
#    ✔ 40420 sequences saved to FASTAS_without_extra/siaP_without_extra.fasta
# → siaQ
#    ✔ 67497 sequences saved to FASTAS_without_extra/siaQ_without_extra.fasta
# → siaT
#    ✔ 70217 sequences saved to FASTAS_without_extra/siaT_without_extra.fasta
#
# ✔ Finished!
