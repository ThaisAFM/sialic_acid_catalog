# %%
import pandas as pd
import os
import glob
from Bio import SeqIO

# %% [markdown]
# ### Filter 1 - Selecting sequences that have the essential signatures

# %%
essential_signatures = {
    "SIAE": "PF03629",
    "kpsD": "PF02563",
    "kpsE": "PTHR32309",
    "kpsM": "PF01061",
    "kpsT": "cd03220",
    "lic3A": "PF06002",
    "lic3B": "PF06002",
    "lst": "PF07922",
    "cpsK": "PF07922",
    "nagA": "cd00854",
    "nagB": "cd01399",
    "nanA": "PTHR42849",
    "nanC": "PF06178",
    "nanE": "PF04131",
    "nanH": "cd15482",
    "nanK": "PTHR18964",
    "nanM": "PF24996",
    "nanQ": "PF04074",
    "nanR": "cd07377",
    "nanT": "cd17316",
    "nanU": "cd08977",
    "neuA": "cd02513",
    "neuB": "cd11615",
    "neuC": "TIGR03568",
    "neuD": "cd03360",
    "neuE": "PF20471",
    "neuO": "cd04647",
    "neuS": "PF07388",
    "ompC": "PF00267",
    "ompF": "PF00267",
    "satA": "PTHR30290",
    "satB": "PTHR43163",
    "satC": "PTHR43297",
    "satD": "PTHR43776",
    "siaM": "PF06808",
    "siaT": "PF06808",
    "siaP": "PF03480",
    "siaQ": "PF04290"  
}

# %%
# Function to parse InterProScan output

def read_interproscan_tsv(file):
    columns = [
        "seq_id", "md5", "length", "analysis", "signature_accession",
        "signature_desc", "start", "end", "evalue", "status",
        "date", "ipr", "ipr_desc", "go", "pathway"
    ]
    try:
        df = pd.read_csv(file, sep="\t", header=None, names=columns, usecols=[0, 4])
        return df
    except Exception as e:
        print(f"Error reading {file}: {e}")
        return pd.DataFrame(columns=["seq_id", "signature_accession"])

# %%
# Identifying IDs that contain the essential signature

interpro_folder = "./interpro_outputs"
output_folder = "./IDs_filter1"

os.makedirs(output_folder, exist_ok=True)

for gene, signature in essential_signatures.items():
    print(f"\n=== Processing {gene} (signature: {signature}) ===")

    interpro_file = f"{gene}_interproscan.tsv"
    interpro_path = os.path.join(interpro_folder, interpro_file)

    if not os.path.exists(interpro_path):
        print(f"[ERROR] File not found: {interpro_path}. Skipping...")
        continue

    df = read_interproscan_tsv(interpro_path)

    if df.empty:
        print(f"[WARNING] Empty file for {gene}.")
        continue

    # --- FILTER BY SIGNATURE ---
    df_filtered = df[df["signature_accession"] == signature]

    # --- REMOVE DUPLICATES ---
    # Deduplicate only by seq_id
    df_filtered = df_filtered.drop_duplicates(subset=["seq_id"])

    # Output file name
    output_file = os.path.join(
        output_folder,
        f"{gene}_IDs_filter1.tsv"
    )

    df_filtered[["seq_id"]].to_csv(output_file, sep="\t", index=False, header=True)

    print(f"Rows found (after deduplication): {len(df_filtered)}")
    print(f"File saved to: {output_file}")
# Out:
# === Processando SIAE (assinatura: PF03629) ===
# Linhas encontradas (após deduplicação): 113516
# Arquivo salvo em: ./IDs_filtro1/SIAE_IDs_filtro1.tsv
#
# === Processando kpsD (assinatura: PF02563) ===
# Linhas encontradas (após deduplicação): 12824
# Arquivo salvo em: ./IDs_filtro1/kpsD_IDs_filtro1.tsv
#
# === Processando kpsE (assinatura: PTHR32309) ===
# Linhas encontradas (após deduplicação): 10297
# Arquivo salvo em: ./IDs_filtro1/kpsE_IDs_filtro1.tsv
#
# === Processando kpsM (assinatura: PF01061) ===
# Linhas encontradas (após deduplicação): 1045
# Arquivo salvo em: ./IDs_filtro1/kpsM_IDs_filtro1.tsv
#
# === Processando kpsT (assinatura: cd03220) ===
# Linhas encontradas (após deduplicação): 12389
# Arquivo salvo em: ./IDs_filtro1/kpsT_IDs_filtro1.tsv
#
# === Processando lic3A (assinatura: PF06002) ===
# Linhas encontradas (após deduplicação): 1394
# Arquivo salvo em: ./IDs_filtro1/lic3A_IDs_filtro1.tsv
#
# === Processando lic3B (assinatura: PF06002) ===
# Linhas encontradas (após deduplicação): 3
# Arquivo salvo em: ./IDs_filtro1/lic3B_IDs_filtro1.tsv
#
# === Processando lst (assinatura: PF07922) ===
# Linhas encontradas (após deduplicação): 2057
# Arquivo salvo em: ./IDs_filtro1/lst_IDs_filtro1.tsv
#
# === Processando cpsK (assinatura: PF07922) ===
# Linhas encontradas (após deduplicação): 33
# Arquivo salvo em: ./IDs_filtro1/cpsK_IDs_filtro1.tsv
#
# === Processando nagA (assinatura: cd00854) ===
# Linhas encontradas (após deduplicação): 123809
# Arquivo salvo em: ./IDs_filtro1/nagA_IDs_filtro1.tsv
#
# === Processando nagB (assinatura: cd01399) ===
# Linhas encontradas (após deduplicação): 141064
# Arquivo salvo em: ./IDs_filtro1/nagB_IDs_filtro1.tsv
#
# === Processando nanA (assinatura: PTHR42849) ===
# Linhas encontradas (após deduplicação): 31161
# Arquivo salvo em: ./IDs_filtro1/nanA_IDs_filtro1.tsv
#
# === Processando nanC (assinatura: PF06178) ===
# Linhas encontradas (após deduplicação): 3427
# Arquivo salvo em: ./IDs_filtro1/nanC_IDs_filtro1.tsv
#
# === Processando nanE (assinatura: PF04131) ===
# Linhas encontradas (após deduplicação): 38622
# Arquivo salvo em: ./IDs_filtro1/nanE_IDs_filtro1.tsv
#
# === Processando nanH (assinatura: cd15482) ===
# Linhas encontradas (após deduplicação): 56427
# Arquivo salvo em: ./IDs_filtro1/nanH_IDs_filtro1.tsv
#
# === Processando nanK (assinatura: PTHR18964) ===
# Linhas encontradas (após deduplicação): 30746
# Arquivo salvo em: ./IDs_filtro1/nanK_IDs_filtro1.tsv
#
# === Processando nanM (assinatura: PF24996) ===
# Linhas encontradas (após deduplicação): 5511
# Arquivo salvo em: ./IDs_filtro1/nanM_IDs_filtro1.tsv
#
# === Processando nanQ (assinatura: PF04074) ===
# Linhas encontradas (após deduplicação): 12456
# Arquivo salvo em: ./IDs_filtro1/nanQ_IDs_filtro1.tsv
#
# === Processando nanR (assinatura: cd07377) ===
# Linhas encontradas (após deduplicação): 11866
# Arquivo salvo em: ./IDs_filtro1/nanR_IDs_filtro1.tsv
#
# === Processando nanT (assinatura: cd17316) ===
# Linhas encontradas (após deduplicação): 8210
# Arquivo salvo em: ./IDs_filtro1/nanT_IDs_filtro1.tsv
#
# === Processando nanU (assinatura: cd08977) ===
# Linhas encontradas (após deduplicação): 150555
# Arquivo salvo em: ./IDs_filtro1/nanU_IDs_filtro1.tsv
#
# === Processando neuA (assinatura: cd02513) ===
# Linhas encontradas (após deduplicação): 46800
# Arquivo salvo em: ./IDs_filtro1/neuA_IDs_filtro1.tsv
#
# === Processando neuB (assinatura: cd11615) ===
# Linhas encontradas (após deduplicação): 54579
# Arquivo salvo em: ./IDs_filtro1/neuB_IDs_filtro1.tsv
#
# === Processando neuC (assinatura: TIGR03568) ===
# Linhas encontradas (após deduplicação): 20703
# Arquivo salvo em: ./IDs_filtro1/neuC_IDs_filtro1.tsv
#
# === Processando neuD (assinatura: cd03360) ===
# Linhas encontradas (após deduplicação): 15906
# Arquivo salvo em: ./IDs_filtro1/neuD_IDs_filtro1.tsv
#
# === Processando neuE (assinatura: PF20471) ===
# Linhas encontradas (após deduplicação): 12
# Arquivo salvo em: ./IDs_filtro1/neuE_IDs_filtro1.tsv
#
# === Processando neuO (assinatura: cd04647) ===
# Linhas encontradas (após deduplicação): 126
# Arquivo salvo em: ./IDs_filtro1/neuO_IDs_filtro1.tsv
#
# === Processando neuS (assinatura: PF07388) ===
# Linhas encontradas (após deduplicação): 22
# Arquivo salvo em: ./IDs_filtro1/neuS_IDs_filtro1.tsv
#
# === Processando ompC (assinatura: PF00267) ===
# Linhas encontradas (após deduplicação): 17380
# Arquivo salvo em: ./IDs_filtro1/ompC_IDs_filtro1.tsv
#
# === Processando ompF (assinatura: PF00267) ===
# Linhas encontradas (após deduplicação): 10653
# Arquivo salvo em: ./IDs_filtro1/ompF_IDs_filtro1.tsv
#
# === Processando satA (assinatura: PTHR30290) ===
# Linhas encontradas (após deduplicação): 4738
# Arquivo salvo em: ./IDs_filtro1/satA_IDs_filtro1.tsv
#
# === Processando satB (assinatura: PTHR43163) ===
# Linhas encontradas (após deduplicação): 4710
# Arquivo salvo em: ./IDs_filtro1/satB_IDs_filtro1.tsv
#
# === Processando satC (assinatura: PTHR43297) ===
# Linhas encontradas (após deduplicação): 952
# Arquivo salvo em: ./IDs_filtro1/satC_IDs_filtro1.tsv
#
# === Processando satD (assinatura: PTHR43776) ===
# Linhas encontradas (após deduplicação): 4887
# Arquivo salvo em: ./IDs_filtro1/satD_IDs_filtro1.tsv
#
# === Processando siaM (assinatura: PF06808) ===
# Linhas encontradas (após deduplicação): 295868
# Arquivo salvo em: ./IDs_filtro1/siaM_IDs_filtro1.tsv
#
# === Processando siaT (assinatura: PF06808) ===
# Linhas encontradas (após deduplicação): 75387
# Arquivo salvo em: ./IDs_filtro1/siaT_IDs_filtro1.tsv
#
# === Processando siaP (assinatura: PF03480) ===
# Linhas encontradas (após deduplicação): 271279
# Arquivo salvo em: ./IDs_filtro1/siaP_IDs_filtro1.tsv
#
# === Processando siaQ (assinatura: PF04290) ===
# Linhas encontradas (após deduplicação): 75718
# Arquivo salvo em: ./IDs_filtro1/siaQ_IDs_filtro1.tsv

# %%
# Retrieving only InterProScan output entries corresponding to sequences
# that contain the essential signature
# Test code for a single protein 
# Optional

# file paths
ids_file = "./interpro_with_essential_signature/cpsK_essential_signature.tsv"     # left
data_file = "./interpro_outputs/cpsK_interproscan.tsv"                            # right
output_file = "cpsK_interpro_filter1.tsv"

# load tables
df_ids = pd.read_csv(ids_file, sep="\t")                    # has header
df_data = pd.read_csv(data_file, sep="\t", header=None)     # no header

# name of the 1st column of df_ids
ids_column = df_ids.columns[0]

# use the first column of df_data (column 0)
df_filtered = df_data[df_data[0].isin(df_ids[ids_column])]

# save
df_filtered.to_csv(output_file, sep="\t", index=False, header=False)

# %%
# Retrieving only InterProScan output entries corresponding to sequences
# that contain the essential signature
# Expanded code for all proteins

# === DIRECTORIES ===
signatures_folder = "./IDs_filter1"
interpro_folder = "./interpro_outputs"        # where *_interproscan.tsv are stored
output_folder = "./interpro_outputs_filter1"

os.makedirs(output_folder, exist_ok=True)

# === LOOP FOR ALL SIGNATURE FILES ===
for sig_file in glob.glob(os.path.join(signatures_folder, "*_IDs_filter1.tsv")):
    
    # extract gene name from filename
    gene = os.path.basename(sig_file).replace("_IDs_filter1.tsv", "")
    
    # corresponding InterProScan file
    interpro_file = os.path.join(interpro_folder, f"{gene}_interproscan.tsv")
    
    # if missing, skip
    if not os.path.exists(interpro_file):
        print(f"[WARNING] InterProScan file not found for {gene}")
        continue
    
    print(f"Processing {gene}...")
    
    # load files
    df_ids = pd.read_csv(sig_file, sep="\t")                    # has header
    df_inter = pd.read_csv(interpro_file, sep="\t", header=None)  # no header
    
    # first column of ID file
    ids_column = df_ids.columns[0]
    
    # filtering
    df_filtered = df_inter[df_inter[0].isin(df_ids[ids_column])]
    
    # save
    out = os.path.join(output_folder, f"{gene}_interproscan_filter1.tsv")
    df_filtered.to_csv(out, sep="\t", index=False, header=False)
    
print("\n### PROCESSING COMPLETED ###")
# Out:
# Processando neuE...
# Processando nanU...
# Processando neuB...
# Processando nanM...
# Processando satA...
# Processando neuO...
# Processando nanT...
# Processando satB...
# Processando siaP...
# Processando kpsT...
# Processando ompC...
# Processando siaQ...
# Processando kpsE...
# Processando nagA...
# Processando kpsD...
# Processando siaM...
# Processando nanR...
# Processando nanE...
# Processando nagB...
# Processando lic3B...
# Processando satC...
# Processando lst...
# Processando neuS...
# Processando nanH...
# Processando neuD...
# Processando kpsM...
# Processando ompF...
# Processando SIAE...
# Processando nanA...
# Processando satD...
# Processando neuC...
# Processando lic3A...
# Processando siaT...
# Processando nanQ...
# Processando cpsK...
# Processando nanK...
# Processando nanC...
# Processando neuA...
#
# ### PROCESSAMENTO CONCLUÍDO ###

# %% [markdown]
# ### Filter 2 - Selecting IDs that have the essential signature and no extra signatures
# Extra signatures are understood to be those that are not present for any of the references

# %% [markdown]
# #### Assembling and verifying the code

# %%
# ----------------------
# Main comparison function
# ----------------------
def compare_with_reference(gene_file, ref_file):

    # 1) Get gene name from file name (e.g., cpsK_interproscan_filtro1.tsv → cpsK)
    filename = os.path.basename(gene_file)
    gene = filename.split("_")[0]   # assumes format "gene_interproscan_filtro1.tsv"
    print(f"Processing gene: {gene}")

    # 2) Read gene InterProScan file
    df_gene = read_interproscan_tsv(gene_file)

    # 3) Read reference file
    df_ref = pd.read_csv(ref_file)

    # 4) Filter references for this gene
    df_ref_gene = df_ref[df_ref["Gene"] == gene]

    if df_ref_gene.empty:
        print(f"No reference found for {gene}.")
        return None

    # 5) Collect all signature_accession used in references
    ref_signatures = set(df_ref_gene["signature_accession"].dropna().unique())
    print(f"Reference signatures ({gene}): {ref_signatures}")

    # 6) Find suspicious signatures (not present in references)
    suspicious_ids = (
        df_gene[
            ~df_gene["signature_accession"].isin(ref_signatures)
        ]["seq_id"]
        .unique()
    )

    print(f"Suspicious IDs: {suspicious_ids}")

    # 7) Create output dataframe
    df_out = df_gene[df_gene["seq_id"].isin(suspicious_ids)]

    # 8) Save
    out = f"{gene}_suspicious_IDs.csv"
    df_out.to_csv(out, index=False)
    print(f"Generated file: {out}")

    return df_out

# %%
compare_with_reference(
    "interpro_outputs_filter1/cpsK_interproscan_filter1.tsv",
    "interproscan_ref_summary.csv"
)
# Out:
# Processando gene: cpsK
# Signatures de referência (cpsK): {'G3DSA:3.40.50.11110', 'PF07922', 'G3DSA:3.30.370.20'}
# IDs suspeitos: ['cpsK_50_uniprot' 'cpsK_57_uniprot']
# Arquivo gerado: cpsK_IDs_suspeitos.csv
#              seq_id  signature_accession
# 16  cpsK_50_uniprot  G3DSA:3.40.50.11110
# 17  cpsK_50_uniprot              PF07922
# 18  cpsK_50_uniprot                 Coil
# 31  cpsK_57_uniprot              PF07922
# 32  cpsK_57_uniprot                 Coil
# 33  cpsK_57_uniprot  G3DSA:3.40.50.11110

# %%
# cpsK - identified sequences with unexpected disordered regions

# %% [markdown]
# #### Expanded code for all proteins

# %%
interpro_folder = "./interpro_outputs_filter1"
ref_file = "./interproscan_ref_summary.csv"
output_folder = "./suspect_IDs"

os.makedirs(output_folder, exist_ok=True)

# Read reference file
df_ref = pd.read_csv(ref_file)

# Process all .tsv files
files = [f for f in os.listdir(interpro_folder) if f.endswith(".tsv")]

print(f"Found {len(files)} files to process.")

for file in files:
    path = os.path.join(interpro_folder, file)
    gene = file.split("_")[0]

    print(f"\n=== Processing gene: {gene} ===")

    df_gene = read_interproscan_tsv(path)
    df_ref_gene = df_ref[df_ref["Gene"] == gene]

    if df_ref_gene.empty:
        print(f"No reference found for {gene}. Skipping...")
        continue

    signatures_ref = set(df_ref_gene["signature_accession"].dropna().astype(str).unique())

    df_gene["signature_accession"] = df_gene["signature_accession"].astype(str)

    suspect_ids = df_gene[
        ~df_gene["signature_accession"].isin(signatures_ref)
    ]["seq_id"].unique()

    df_output = df_gene[df_gene["seq_id"].isin(suspect_ids)]

    outpath = os.path.join(output_folder, f"{gene}_suspect_IDs.tsv")
    df_output[["seq_id"]].drop_duplicates().to_csv(
        outpath,
        sep="\t",
        index=False
    )

    print(f"File generated: {outpath} ({len(df_output)} rows)")

print("\nProcessing completed! 👍")
# Out:
# Encontrados 38 arquivos para processar.
#
# === Processando gene: siaQ ===
# Arquivo gerado: ./IDs_suspeitos/siaQ_IDs_suspeitos.tsv (31541 linhas)
#
# === Processando gene: lst ===
# Arquivo gerado: ./IDs_suspeitos/lst_IDs_suspeitos.tsv (112 linhas)
#
# === Processando gene: ompF ===
# Arquivo gerado: ./IDs_suspeitos/ompF_IDs_suspeitos.tsv (9383 linhas)
#
# === Processando gene: neuC ===
# Arquivo gerado: ./IDs_suspeitos/neuC_IDs_suspeitos.tsv (11942 linhas)
#
# === Processando gene: neuE ===
# Arquivo gerado: ./IDs_suspeitos/neuE_IDs_suspeitos.tsv (2 linhas)
#
# === Processando gene: nanC ===
# Arquivo gerado: ./IDs_suspeitos/nanC_IDs_suspeitos.tsv (10536 linhas)
#
# === Processando gene: siaT ===
# Arquivo gerado: ./IDs_suspeitos/siaT_IDs_suspeitos.tsv (25967 linhas)
#
# === Processando gene: satC ===
# Arquivo gerado: ./IDs_suspeitos/satC_IDs_suspeitos.tsv (9614 linhas)
#
# === Processando gene: neuB ===
# Arquivo gerado: ./IDs_suspeitos/neuB_IDs_suspeitos.tsv (269311 linhas)
#
# === Processando gene: nanA ===
# Arquivo gerado: ./IDs_suspeitos/nanA_IDs_suspeitos.tsv (178557 linhas)
#
# === Processando gene: siaM ===
# Arquivo gerado: ./IDs_suspeitos/siaM_IDs_suspeitos.tsv (102035 linhas)
#
# === Processando gene: SIAE ===
# Arquivo gerado: ./IDs_suspeitos/SIAE_IDs_suspeitos.tsv (414368 linhas)
#
# === Processando gene: ompC ===
# Arquivo gerado: ./IDs_suspeitos/ompC_IDs_suspeitos.tsv (207738 linhas)
#
# === Processando gene: nanK ===
# Arquivo gerado: ./IDs_suspeitos/nanK_IDs_suspeitos.tsv (132474 linhas)
#
# === Processando gene: kpsT ===
# Arquivo gerado: ./IDs_suspeitos/kpsT_IDs_suspeitos.tsv (9550 linhas)
#
# === Processando gene: neuA ===
# Arquivo gerado: ./IDs_suspeitos/neuA_IDs_suspeitos.tsv (216427 linhas)
#
# === Processando gene: siaP ===
# Arquivo gerado: ./IDs_suspeitos/siaP_IDs_suspeitos.tsv (1649317 linhas)
#
# === Processando gene: nanQ ===
# Arquivo gerado: ./IDs_suspeitos/nanQ_IDs_suspeitos.tsv (5920 linhas)
#
# === Processando gene: lic3B ===
# Arquivo gerado: ./IDs_suspeitos/lic3B_IDs_suspeitos.tsv (0 linhas)
#
# === Processando gene: nanT ===
# Arquivo gerado: ./IDs_suspeitos/nanT_IDs_suspeitos.tsv (37518 linhas)
#
# === Processando gene: nagB ===
# Arquivo gerado: ./IDs_suspeitos/nagB_IDs_suspeitos.tsv (529826 linhas)
#
# === Processando gene: nagA ===
# Arquivo gerado: ./IDs_suspeitos/nagA_IDs_suspeitos.tsv (97972 linhas)
#
# === Processando gene: satA ===
# Arquivo gerado: ./IDs_suspeitos/satA_IDs_suspeitos.tsv (39436 linhas)
#
# === Processando gene: neuD ===
# Arquivo gerado: ./IDs_suspeitos/neuD_IDs_suspeitos.tsv (24100 linhas)
#
# === Processando gene: kpsM ===
# Arquivo gerado: ./IDs_suspeitos/kpsM_IDs_suspeitos.tsv (272 linhas)
#
# === Processando gene: satD ===
# Arquivo gerado: ./IDs_suspeitos/satD_IDs_suspeitos.tsv (34756 linhas)
#
# === Processando gene: kpsD ===
# Arquivo gerado: ./IDs_suspeitos/kpsD_IDs_suspeitos.tsv (120745 linhas)
#
# === Processando gene: nanE ===
# Arquivo gerado: ./IDs_suspeitos/nanE_IDs_suspeitos.tsv (19511 linhas)
#
# === Processando gene: nanU ===
# Arquivo gerado: ./IDs_suspeitos/nanU_IDs_suspeitos.tsv (790619 linhas)
#
# === Processando gene: satB ===
# Arquivo gerado: ./IDs_suspeitos/satB_IDs_suspeitos.tsv (647 linhas)
#
# === Processando gene: cpsK ===
# Arquivo gerado: ./IDs_suspeitos/cpsK_IDs_suspeitos.tsv (6 linhas)
#
# === Processando gene: kpsE ===
# Arquivo gerado: ./IDs_suspeitos/kpsE_IDs_suspeitos.tsv (23665 linhas)
#
# === Processando gene: neuO ===
# Arquivo gerado: ./IDs_suspeitos/neuO_IDs_suspeitos.tsv (141 linhas)
#
# === Processando gene: neuS ===
# Arquivo gerado: ./IDs_suspeitos/neuS_IDs_suspeitos.tsv (0 linhas)
#
# === Processando gene: nanR ===
# Arquivo gerado: ./IDs_suspeitos/nanR_IDs_suspeitos.tsv (20517 linhas)
#
# === Processando gene: nanM ===
# Arquivo gerado: ./IDs_suspeitos/nanM_IDs_suspeitos.tsv (7200 linhas)
#
# === Processando gene: lic3A ===
# Arquivo gerado: ./IDs_suspeitos/lic3A_IDs_suspeitos.tsv (504 linhas)
#
# === Processando gene: nanH ===
# Arquivo gerado: ./IDs_suspeitos/nanH_IDs_suspeitos.tsv (326844 linhas)
#
# Processamento concluído! 👍

# %%
# Só contar quantos IDs tem em cada arquivo de IDs_suspeitos

def contar_ids_unicos(pasta):
    arquivos = [f for f in os.listdir(pasta) if f.endswith(".tsv")]

    resultados = []

    for arq in arquivos:
        caminho = os.path.join(pasta, arq)

        # Lê o CSV
        df = pd.read_csv(caminho)

        # Conta IDs únicos
        ids_unicos = df["seq_id"].nunique()

        resultados.append({
            "arquivo": arq,
            "ids_unicos": ids_unicos
        })

    # Retorna resultado como DataFrame
    return pd.DataFrame(resultados)


# ===== Executar =====
resultado = contar_ids_unicos("./IDs_suspeitos")
print(resultado)
# Out:
#                     arquivo  ids_unicos
# 0    siaP_IDs_suspeitos.tsv      230859
# 1    kpsT_IDs_suspeitos.tsv         944
# 2   lic3A_IDs_suspeitos.tsv         116
# 3    nagB_IDs_suspeitos.tsv       55208
# 4    nanT_IDs_suspeitos.tsv        4038
# 5    nanE_IDs_suspeitos.tsv        1959
# 6    satB_IDs_suspeitos.tsv          79
# 7   lic3B_IDs_suspeitos.tsv           0
# 8    siaM_IDs_suspeitos.tsv       17296
# 9    neuC_IDs_suspeitos.tsv        1513
# 10   nanH_IDs_suspeitos.tsv       33477
# 11   nanC_IDs_suspeitos.tsv        2398
# 12   nanM_IDs_suspeitos.tsv        1053
# 13   kpsD_IDs_suspeitos.tsv        9886
# 14   neuO_IDs_suspeitos.tsv          12
# 15   ompF_IDs_suspeitos.tsv         596
# 16   neuS_IDs_suspeitos.tsv           0
# 17   nanQ_IDs_suspeitos.tsv        1023
# 18   ompC_IDs_suspeitos.tsv       12179
# 19   nanA_IDs_suspeitos.tsv       17160
# 20   nagA_IDs_suspeitos.tsv        8986
# 21   SIAE_IDs_suspeitos.tsv       53340
# 22   nanU_IDs_suspeitos.tsv      123177
# 23   satA_IDs_suspeitos.tsv        3816
# 24   kpsM_IDs_suspeitos.tsv          33
# 25   neuB_IDs_suspeitos.tsv       23368
# 26   neuE_IDs_suspeitos.tsv           1
# 27   satC_IDs_suspeitos.tsv         556
# 28   cpsK_IDs_suspeitos.tsv           2
# 29    lst_IDs_suspeitos.tsv          34
# 30   nanK_IDs_suspeitos.tsv       19448
# 31   satD_IDs_suspeitos.tsv        3206
# 32   nanR_IDs_suspeitos.tsv        1349
# 33   kpsE_IDs_suspeitos.tsv        3699
# 34   neuD_IDs_suspeitos.tsv        2627
# 35   siaT_IDs_suspeitos.tsv        5170
# 36   neuA_IDs_suspeitos.tsv       24736
# 37   siaQ_IDs_suspeitos.tsv        8221

# %% [markdown]
# ### Compiling FASTA files

# %%
# Code to identify which IDs are present in IDs_filter1 but not in suspect_IDs
# In other words, retrieve IDs of sequences that contain the essential signature
# and remove IDs of sequences that contain additional signatures

# Writing the code for a single protein set

# Read files (automatically detects separator)
df_filter1 = pd.read_csv("./IDs_filter1/cpsK_IDs_filter1.tsv", sep=None, engine="python")
df_suspects = pd.read_csv("./suspect_IDs/cpsK_suspect_IDs.csv", sep=None, engine="python")

# Extract ID lists
ids_filter1 = set(df_filter1["seq_id"])
ids_suspects = set(df_suspects["seq_id"])

# IDs present in filter1 but not in suspects
unique_ids = sorted(ids_filter1 - ids_suspects)

# Save as txt (one ID per line)
with open("cpsK_exclusive_IDs.txt", "w") as f:
    for seqid in unique_ids:
        f.write(seqid + "\n")

print("File generated: cpsK_exclusive_IDs.txt")
# Out:
# Arquivo gerado: cpsK_IDs_exclusivos.txt

# %%
# Expanded code to process all files to be curated

dir_filter1 = "IDs_filter1"
dir_suspects = "IDs_suspects"
dir_output = "IDs_curated"

os.makedirs(dir_output, exist_ok=True)

# List files in directories
files_filter1 = {f.split("_")[0]: f for f in os.listdir(dir_filter1)}
files_suspects = {f.split("_")[0]: f for f in os.listdir(dir_suspects)}

genes = sorted(set(files_filter1.keys()) & set(files_suspects.keys()))

for gene in genes:
    file_filter1 = os.path.join(dir_filter1, files_filter1[gene])
    file_suspects = os.path.join(dir_suspects, files_suspects[gene])

    # Read files (automatic separator detection)
    df_filter1 = pd.read_csv(file_filter1, engine="python")
    df_suspects = pd.read_csv(file_suspects, engine="python")

    # Extract IDs
    ids_filter1 = set(df_filter1["seq_id"])
    ids_suspects = set(df_suspects["seq_id"])

    # Difference
    unique_ids = sorted(ids_filter1 - ids_suspects)

    # Save output file
    out_file = os.path.join(dir_output, f"{gene}_curated_IDs.tsv")
    df_out = pd.DataFrame({"seq_id": unique_ids})
    df_out.to_csv(out_file, sep="\t", index=False, header=True)

    print(f"{gene}: {len(unique_ids)} curated IDs saved.")

print("\n✔️ Process completed!")
# Out:
# SIAE: 60176 IDs curados salvos.
# cpsK: 31 IDs curados salvos.
# kpsD: 2938 IDs curados salvos.
# kpsE: 6598 IDs curados salvos.
# kpsM: 1012 IDs curados salvos.
# kpsT: 11445 IDs curados salvos.
# lic3A: 1278 IDs curados salvos.
# lic3B: 3 IDs curados salvos.
# lst: 2023 IDs curados salvos.
# nagA: 114823 IDs curados salvos.
# nagB: 85856 IDs curados salvos.
# nanA: 14001 IDs curados salvos.
# nanC: 1029 IDs curados salvos.
# nanE: 36663 IDs curados salvos.
# nanH: 22950 IDs curados salvos.
# nanK: 11298 IDs curados salvos.
# nanM: 4458 IDs curados salvos.
# nanQ: 11433 IDs curados salvos.
# nanR: 10517 IDs curados salvos.
# nanT: 4172 IDs curados salvos.
# nanU: 27378 IDs curados salvos.
# neuA: 22064 IDs curados salvos.
# neuB: 31211 IDs curados salvos.
# neuC: 19190 IDs curados salvos.
# neuD: 13279 IDs curados salvos.
# neuE: 11 IDs curados salvos.
# neuO: 114 IDs curados salvos.
# neuS: 22 IDs curados salvos.
# ompC: 5201 IDs curados salvos.
# ompF: 10057 IDs curados salvos.
# satA: 922 IDs curados salvos.
# satB: 4631 IDs curados salvos.
# satC: 396 IDs curados salvos.
# satD: 1681 IDs curados salvos.
# siaM: 278572 IDs curados salvos.
# siaP: 40420 IDs curados salvos.
# siaQ: 67497 IDs curados salvos.
# siaT: 70217 IDs curados salvos.
#
# ✔️ Processo finalizado!

# %%
# Extracting FASTA sequences with essential signatures

dir_fastas = "merged_nr_fastas"                  # Original FASTA files
dir_ids = "IDs_filter1"                          # TSV files with approved seq_id
dir_output = "FASTAS_with_essential_signature"   # Final FASTA files

os.makedirs(dir_output, exist_ok=True)

# Map files by gene (before the first "_")
fastas = {f.split("_")[0]: f for f in os.listdir(dir_fastas) if f.endswith(".fasta")}
idfiles = {f.split("_")[0]: f for f in os.listdir(dir_ids) if f.endswith(".tsv")}

# Genes in common
genes = sorted(set(fastas.keys()) & set(idfiles.keys()))

print(f"Processing {len(genes)} genes...\n")

for gene in genes:

    fasta_path = os.path.join(dir_fastas, fastas[gene])
    ids_path = os.path.join(dir_ids, idfiles[gene])

    print(f"→ {gene}")

    # Read approved IDs
    df = pd.read_csv(ids_path, sep="\t")
    approved_ids = set(df["seq_id"].astype(str))

    # Read original FASTA
    records = list(SeqIO.parse(fasta_path, "fasta"))

    # Filter sequences whose header is in the list
    filtered = [
        r for r in records
        if r.id in approved_ids
    ]

    # Output file
    out_fasta = os.path.join(dir_output, f"{gene}_with_essential_signature.fasta")

    SeqIO.write(filtered, out_fasta, "fasta")

    print(f"   ✔ {len(filtered)} sequences saved to {out_fasta}")

print("\n✔ Finished!")
# Out:
# Processando 38 genes...
#
# → SIAE
#    ✔ 113516 sequências salvas em FASTAS_with_essencial_signature/SIAE_with_essencial_signature.fasta
# → cpsK
#    ✔ 33 sequências salvas em FASTAS_with_essencial_signature/cpsK_with_essencial_signature.fasta
# → kpsD
#    ✔ 12824 sequências salvas em FASTAS_with_essencial_signature/kpsD_with_essencial_signature.fasta
# → kpsE
#    ✔ 10297 sequências salvas em FASTAS_with_essencial_signature/kpsE_with_essencial_signature.fasta
# → kpsM
#    ✔ 1045 sequências salvas em FASTAS_with_essencial_signature/kpsM_with_essencial_signature.fasta
# → kpsT
#    ✔ 12389 sequências salvas em FASTAS_with_essencial_signature/kpsT_with_essencial_signature.fasta
# → lic3A
#    ✔ 1394 sequências salvas em FASTAS_with_essencial_signature/lic3A_with_essencial_signature.fasta
# → lic3B
#    ✔ 3 sequências salvas em FASTAS_with_essencial_signature/lic3B_with_essencial_signature.fasta
# → lst
#    ✔ 2057 sequências salvas em FASTAS_with_essencial_signature/lst_with_essencial_signature.fasta
# → nagA
#    ✔ 123809 sequências salvas em FASTAS_with_essencial_signature/nagA_with_essencial_signature.fasta
# → nagB
#    ✔ 141064 sequências salvas em FASTAS_with_essencial_signature/nagB_with_essencial_signature.fasta
# → nanA
#    ✔ 31161 sequências salvas em FASTAS_with_essencial_signature/nanA_with_essencial_signature.fasta
# → nanC
#    ✔ 3427 sequências salvas em FASTAS_with_essencial_signature/nanC_with_essencial_signature.fasta
# → nanE
#    ✔ 38622 sequências salvas em FASTAS_with_essencial_signature/nanE_with_essencial_signature.fasta
# → nanH
#    ✔ 56427 sequências salvas em FASTAS_with_essencial_signature/nanH_with_essencial_signature.fasta
# → nanK
#    ✔ 30746 sequências salvas em FASTAS_with_essencial_signature/nanK_with_essencial_signature.fasta
# → nanM
#    ✔ 5511 sequências salvas em FASTAS_with_essencial_signature/nanM_with_essencial_signature.fasta
# → nanQ
#    ✔ 12456 sequências salvas em FASTAS_with_essencial_signature/nanQ_with_essencial_signature.fasta
# → nanR
#    ✔ 11866 sequências salvas em FASTAS_with_essencial_signature/nanR_with_essencial_signature.fasta
# → nanT
#    ✔ 8210 sequências salvas em FASTAS_with_essencial_signature/nanT_with_essencial_signature.fasta
# → nanU
#    ✔ 150555 sequências salvas em FASTAS_with_essencial_signature/nanU_with_essencial_signature.fasta
# → neuA
#    ✔ 46800 sequências salvas em FASTAS_with_essencial_signature/neuA_with_essencial_signature.fasta
# → neuB
#    ✔ 54579 sequências salvas em FASTAS_with_essencial_signature/neuB_with_essencial_signature.fasta
# → neuC
#    ✔ 20703 sequências salvas em FASTAS_with_essencial_signature/neuC_with_essencial_signature.fasta
# → neuD
#    ✔ 15906 sequências salvas em FASTAS_with_essencial_signature/neuD_with_essencial_signature.fasta
# → neuE
#    ✔ 12 sequências salvas em FASTAS_with_essencial_signature/neuE_with_essencial_signature.fasta
# → neuO
#    ✔ 126 sequências salvas em FASTAS_with_essencial_signature/neuO_with_essencial_signature.fasta
# → neuS
#    ✔ 22 sequências salvas em FASTAS_with_essencial_signature/neuS_with_essencial_signature.fasta
# → ompC
#    ✔ 17380 sequências salvas em FASTAS_with_essencial_signature/ompC_with_essencial_signature.fasta
# → ompF
#    ✔ 10653 sequências salvas em FASTAS_with_essencial_signature/ompF_with_essencial_signature.fasta
# → satA
#    ✔ 4738 sequências salvas em FASTAS_with_essencial_signature/satA_with_essencial_signature.fasta
# → satB
#    ✔ 4710 sequências salvas em FASTAS_with_essencial_signature/satB_with_essencial_signature.fasta
# → satC
#    ✔ 952 sequências salvas em FASTAS_with_essencial_signature/satC_with_essencial_signature.fasta
# → satD
#    ✔ 4887 sequências salvas em FASTAS_with_essencial_signature/satD_with_essencial_signature.fasta
# → siaM
#    ✔ 295868 sequências salvas em FASTAS_with_essencial_signature/siaM_with_essencial_signature.fasta
# → siaP
#    ✔ 271279 sequências salvas em FASTAS_with_essencial_signature/siaP_with_essencial_signature.fasta
# → siaQ
#    ✔ 75718 sequências salvas em FASTAS_with_essencial_signature/siaQ_with_essencial_signature.fasta
# → siaT
#    ✔ 75387 sequências salvas em FASTAS_with_essencial_signature/siaT_with_essencial_signature.fasta
#
# ✔ Finalizado!

# %%
# Extracting FASTA sequences with essential signatures and without any extra signatures

dir_fastas = "merged_nr_fastas"        # Original FASTA files
dir_ids = "IDs_cured"                  # TSV files with approved seq_id
dir_output = "FASTAS_cured"            # Final FASTA files

os.makedirs(dir_output, exist_ok=True)

# Map files by gene (before the first "_")
fastas = {f.split("_")[0]: f for f in os.listdir(dir_fastas) if f.endswith(".fasta")}
idfiles = {f.split("_")[0]: f for f in os.listdir(dir_ids) if f.endswith(".tsv")}

# Genes in common
genes = sorted(set(fastas.keys()) & set(idfiles.keys()))

print(f"Processing {len(genes)} genes...\n")

for gene in genes:

    fasta_path = os.path.join(dir_fastas, fastas[gene])
    ids_path = os.path.join(dir_ids, idfiles[gene])

    print(f"→ {gene}")

    # Read approved IDs
    df = pd.read_csv(ids_path, sep="\t")
    approved_ids = set(df["seq_id"].astype(str))

    # Read original FASTA
    records = list(SeqIO.parse(fasta_path, "fasta"))

    # Filter sequences whose header is in the list
    filtered = [
        r for r in records
        if r.id in approved_ids
    ]

    # Output file
    out_fasta = os.path.join(dir_output, f"{gene}_cured.fasta")

    SeqIO.write(filtered, out_fasta, "fasta")

    print(f"   ✔ {len(filtered)} sequences saved to {out_fasta}")

print("\n✔ Finished!")
# Out:
# Processando 38 genes...
#
# → SIAE
#    ✔ 60176 sequências salvas em FASTAS_curados/SIAE_curado.fasta
# → cpsK
#    ✔ 31 sequências salvas em FASTAS_curados/cpsK_curado.fasta
# → kpsD
#    ✔ 2938 sequências salvas em FASTAS_curados/kpsD_curado.fasta
# → kpsE
#    ✔ 6598 sequências salvas em FASTAS_curados/kpsE_curado.fasta
# → kpsM
#    ✔ 1012 sequências salvas em FASTAS_curados/kpsM_curado.fasta
# → kpsT
#    ✔ 11445 sequências salvas em FASTAS_curados/kpsT_curado.fasta
# → lic3A
#    ✔ 1278 sequências salvas em FASTAS_curados/lic3A_curado.fasta
# → lic3B
#    ✔ 3 sequências salvas em FASTAS_curados/lic3B_curado.fasta
# → lst
#    ✔ 2023 sequências salvas em FASTAS_curados/lst_curado.fasta
# → nagA
#    ✔ 114823 sequências salvas em FASTAS_curados/nagA_curado.fasta
# → nagB
#    ✔ 85856 sequências salvas em FASTAS_curados/nagB_curado.fasta
# → nanA
#    ✔ 14001 sequências salvas em FASTAS_curados/nanA_curado.fasta
# → nanC
#    ✔ 1029 sequências salvas em FASTAS_curados/nanC_curado.fasta
# → nanE
#    ✔ 36663 sequências salvas em FASTAS_curados/nanE_curado.fasta
# → nanH
#    ✔ 22950 sequências salvas em FASTAS_curados/nanH_curado.fasta
# → nanK
#    ✔ 11298 sequências salvas em FASTAS_curados/nanK_curado.fasta
# → nanM
#    ✔ 4458 sequências salvas em FASTAS_curados/nanM_curado.fasta
# → nanQ
#    ✔ 11433 sequências salvas em FASTAS_curados/nanQ_curado.fasta
# → nanR
#    ✔ 10517 sequências salvas em FASTAS_curados/nanR_curado.fasta
# → nanT
#    ✔ 4172 sequências salvas em FASTAS_curados/nanT_curado.fasta
# → nanU
#    ✔ 27378 sequências salvas em FASTAS_curados/nanU_curado.fasta
# → neuA
#    ✔ 22064 sequências salvas em FASTAS_curados/neuA_curado.fasta
# → neuB
#    ✔ 31211 sequências salvas em FASTAS_curados/neuB_curado.fasta
# → neuC
#    ✔ 19190 sequências salvas em FASTAS_curados/neuC_curado.fasta
# → neuD
#    ✔ 13279 sequências salvas em FASTAS_curados/neuD_curado.fasta
# → neuE
#    ✔ 11 sequências salvas em FASTAS_curados/neuE_curado.fasta
# → neuO
#    ✔ 114 sequências salvas em FASTAS_curados/neuO_curado.fasta
# → neuS
#    ✔ 22 sequências salvas em FASTAS_curados/neuS_curado.fasta
# → ompC
#    ✔ 5201 sequências salvas em FASTAS_curados/ompC_curado.fasta
# → ompF
#    ✔ 10057 sequências salvas em FASTAS_curados/ompF_curado.fasta
# → satA
#    ✔ 922 sequências salvas em FASTAS_curados/satA_curado.fasta
# → satB
#    ✔ 4631 sequências salvas em FASTAS_curados/satB_curado.fasta
# → satC
#    ✔ 396 sequências salvas em FASTAS_curados/satC_curado.fasta
# → satD
#    ✔ 1681 sequências salvas em FASTAS_curados/satD_curado.fasta
# → siaM
#    ✔ 278572 sequências salvas em FASTAS_curados/siaM_curado.fasta
# → siaP
#    ✔ 40420 sequências salvas em FASTAS_curados/siaP_curado.fasta
# → siaQ
#    ✔ 67497 sequências salvas em FASTAS_curados/siaQ_curado.fasta
# → siaT
#    ✔ 70217 sequências salvas em FASTAS_curados/siaT_curado.fasta
#
# ✔ Finalizado!
