# %%
import os
from Bio import SeqIO

# %%
# Directories
input_dir = "./"                 # current directory
output_dir = "FASTAS_aligned"    # output directory

os.makedirs(output_dir, exist_ok=True)

# outfmt6 extension
outfmt_ext = ".outfmt6"

for file in os.listdir(input_dir):
    if file.endswith("_nr.fasta"):

        fasta_path = os.path.join(input_dir, file)
        base = file.replace(".fasta", "")
        outfmt_path = os.path.join(input_dir, base + outfmt_ext)

        if not os.path.exists(outfmt_path):
            print(f"⚠ outfmt6 file not found for {file}")
            continue

        print(f"Processing: {file}")

        # -----------------------------
        # Read aligned query IDs
        # -----------------------------
        aligned_ids = set()

        with open(outfmt_path) as f:
            for line in f:
                if line.strip():
                    qid = line.split("\t")[0]
                    aligned_ids.add(qid)

        if not aligned_ids:
            print(f"  No alignments found in {outfmt_path}")
            continue

        # -----------------------------
        # Filter FASTA
        # -----------------------------
        records = []
        for record in SeqIO.parse(fasta_path, "fasta"):
            if record.id in aligned_ids:
                records.append(record)

        # -----------------------------
        # Write output
        # -----------------------------
        out_fasta = os.path.join(
            output_dir,
            file.replace("_nr.fasta", "_aligned.fasta")
        )

        SeqIO.write(records, out_fasta, "fasta")

        print(f"  -> {len(records)} sequences saved to {out_fasta}")

print("\n✅ Finished.")
# Out:
# Processing: kpsT_merged_nr.fasta
#   -> 16283 sequences saved to FASTAS_aligned/kpsT_merged_aligned.fasta
# Processing: nanA_merged_nr.fasta
#   -> 102021 sequences saved to FASTAS_aligned/nanA_merged_aligned.fasta
# Processing: nanR_merged_nr.fasta
#   -> 9482 sequences saved to FASTAS_aligned/nanR_merged_aligned.fasta
# Processing: nanE_merged_nr.fasta
#   -> 39141 sequences saved to FASTAS_aligned/nanE_merged_aligned.fasta
# Processing: cpsK_merged_nr.fasta
#   -> 33 sequences saved to FASTAS_aligned/cpsK_merged_aligned.fasta
# Processing: neuA_merged_nr.fasta
#   -> 53332 sequences saved to FASTAS_aligned/neuA_merged_aligned.fasta
# Processing: nanC_merged_nr.fasta
#   -> 1760 sequences saved to FASTAS_aligned/nanC_merged_aligned.fasta
# Processing: nanT_merged_nr.fasta
#   -> 12762 sequences saved to FASTAS_aligned/nanT_merged_aligned.fasta
# Processing: siaQ_merged_nr.fasta
#   -> 320875 sequences saved to FASTAS_aligned/siaQ_merged_aligned.fasta
# Processing: nanM_merged_nr.fasta
#   -> 5888 sequences saved to FASTAS_aligned/nanM_merged_aligned.fasta
# Processing: satA_nr.fasta
#   -> 4739 sequences saved to FASTAS_aligned/satA_aligned.fasta
# Processing: lst_merged_nr.fasta
#   -> 2053 sequences saved to FASTAS_aligned/lst_merged_aligned.fasta
# Processing: nanK_merged_nr.fasta
#   -> 30355 sequences saved to FASTAS_aligned/nanK_merged_aligned.fasta
# Processing: kpsD_merged_nr.fasta
#   -> 13894 sequences saved to FASTAS_aligned/kpsD_merged_aligned.fasta
# Processing: neuC_merged_nr.fasta
#   -> 104918 sequences saved to FASTAS_aligned/neuC_merged_aligned.fasta
# Processing: nanQ_merged_nr.fasta
#   -> 11121 sequences saved to FASTAS_aligned/nanQ_merged_aligned.fasta
# Processing: nagB_merged_nr.fasta
#   -> 170625 sequences saved to FASTAS_aligned/nagB_merged_aligned.fasta
# Processing: neuS_merged_nr.fasta
#   -> 25 sequences saved to FASTAS_aligned/neuS_merged_aligned.fasta
# Processing: nagA_merged_nr.fasta
#   -> 200329 sequences saved to FASTAS_aligned/nagA_merged_aligned.fasta
# Processing: lic3A_merged_nr.fasta
#   -> 1400 sequences saved to FASTAS_aligned/lic3A_merged_aligned.fasta
# Processing: nanH_merged_nr.fasta
#   -> 47462 sequences saved to FASTAS_aligned/nanH_merged_aligned.fasta
# Processing: SIAE_merged_nr.fasta
#   -> 108999 sequences saved to FASTAS_aligned/SIAE_merged_aligned.fasta
# Processing: siaT_merged_nr.fasta
#   -> 74864 sequences saved to FASTAS_aligned/siaT_merged_aligned.fasta
# Processing: neuB_merged_nr.fasta
#   -> 75291 sequences saved to FASTAS_aligned/neuB_merged_aligned.fasta
# Processing: neuO_merged_nr.fasta
#   -> 134 sequences saved to FASTAS_aligned/neuO_merged_aligned.fasta
# Processing: kpsE_merged_nr.fasta
#   -> 9399 sequences saved to FASTAS_aligned/kpsE_merged_aligned.fasta
# Processing: ompC_merged_nr.fasta
#   -> 18996 sequences saved to FASTAS_aligned/ompC_merged_aligned.fasta
# Processing: satD_nr.fasta
#   -> 4887 sequences saved to FASTAS_aligned/satD_aligned.fasta
# Processing: lic3B_merged_nr.fasta
#   -> 3 sequences saved to FASTAS_aligned/lic3B_merged_aligned.fasta
# Processing: ompF_merged_nr.fasta
#   -> 10992 sequences saved to FASTAS_aligned/ompF_merged_aligned.fasta
# Processing: siaP_merged_nr.fasta
#   -> 219932 sequences saved to FASTAS_aligned/siaP_merged_aligned.fasta
# Processing: satB_nr.fasta
#   -> 4710 sequences saved to FASTAS_aligned/satB_aligned.fasta
# Processing: nanU_merged_nr.fasta
#   -> 257310 sequences saved to FASTAS_aligned/nanU_merged_aligned.fasta
# Processing: neuD_merged_nr.fasta
#   -> 3932 sequences saved to FASTAS_aligned/neuD_merged_aligned.fasta
# Processing: satC_nr.fasta
#   -> 957 sequences saved to FASTAS_aligned/satC_aligned.fasta
# Processing: neuE_merged_nr.fasta
#   -> 12 sequences saved to FASTAS_aligned/neuE_merged_aligned.fasta
# Processing: siaM_merged_nr.fasta
#   -> 315243 sequences saved to FASTAS_aligned/siaM_merged_aligned.fasta
# Processing: kpsM_merged_nr.fasta
#   -> 961 sequences saved to FASTAS_aligned/kpsM_merged_aligned.fasta
#
# ✅ Finished.
